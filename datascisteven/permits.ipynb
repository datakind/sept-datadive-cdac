# %%
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("data/Street_Construction_Permits.csv", low_memory=False)
df.head()
# Out:
#     PermitNumber  ApplicationTrackingID  SequenceNumber  \
# 0  Q012007305130                    NaN             NaN
# 1  X042012258017                    NaN             NaN
# 2  X012010223030                    NaN             NaN
# 3  X012006219032                    NaN             NaN
# 4  X011999076002                    NaN             NaN
#
#   ApplicationTypeShortDesc PermitStatusID          PermitStatusShortDesc  \
# 0                      NaN            015  DELINQUENT CUTFORM/COMPACTION
# 1                      NaN            030                        EXPIRED
# 2                      NaN            030                        EXPIRED
# 3                      NaN            030                        EXPIRED
# 4                      NaN            015  DELINQUENT CUTFORM/COMPACTION
#
#    PermitSeriesID         PermitSeriesShortDesc PermitTypeID  \
# 0               1         STREET OPENING PERMIT         0162
# 1               4  SIDEWALK CONSTRUCTION PERMIT         0401
# ...

# %% [markdown]
# df.columns

# %%
df.columns
# Out:
# Index(['PermitNumber', 'ApplicationTrackingID', 'SequenceNumber',
#        'ApplicationTypeShortDesc', 'PermitStatusID', 'PermitStatusShortDesc',
#        'PermitSeriesID', 'PermitSeriesShortDesc', 'PermitTypeID',
#        'PermitTypeDesc', 'PermitNumberOfZones', 'PermitLinearFeet',
#        'PermitTotalSqFeet', 'PermitEstimatedNumberOfCuts', 'EquipmentTypeDesc',
#        'NumberOfContainers', 'NumberOfMiniContainers', 'SpecificStipulations',
#        'PreviousPermitNumber', 'NextPermitNumber', 'EmergencyIssueDate',
#        'PermitIssueDate', 'IssuedWorkStartDate', 'IssuedWorkEndDate',
#        'BoroughName', 'PermitHouseNumber', 'OnStreetName', 'FromStreetName',
#        'ToStreetName', 'PermitteeName', 'PermitPurposeComments',
#        'PermitLocationComments', 'PavementShortDesc', 'SideWalkShortDesc',
#        'CreatedOn', 'ModifiedOn'],
#       dtype='object')

# %%
df.PermitTypeDesc.unique()
# Out:
# array(['NYC PARKS - RECONSTRUCTION CONTRACT', 'REPAIR SIDEWALK',
#        'REPAIR GAS', 'REPAIR WATER', 'MAJOR INSTALLATION - GAS',
#        'REPLACE SIDEWALK', 'PLACE CRANE OR SHOVEL ON STREET',
#        'UTILITY MANHOLE EMBARGO PERMIT', 'COMMERCIAL REFUSE CONTAINER',
#        'REPAIR TRAFFIC STREET LIGHT',
#        'OCCUPANCY OF ROADWAY AS STIPULATED', 'REPAIR WATER - PROTECTED',
#        'PAVE STREET-W/ ENGINEERING & INSP FEE',
#        'REGRADE HARDWARE U/C ONLY', 'SCHEDULE A',
#        'MAJOR INSTALLATIONS - GAS-PROTECTED',
#        'TEST PITS, CORES OR BORING', 'MAJOR INSTALLATIONS - HIGH VOLTAGE',
#        'OCCUPANCY OF SIDEWALK AS STIPULATED', 'OVERSIZED VEHICLES',
#        'COMMERCIAL REFUSE CONTAINER CRITICAL STS',
#        'CONSTRUCT OR ALTER MANHOLE &/OR CASTING',
#        'UTILITY MNAHOLE EMBARGO PERMIT',
#        'PLACE EQUIPMENT OTHER THAN CRANE OR SHOV',
#        'DDC CONTRACTOR MAJOR RECONSTRUCTION-PROT',
#        'PLACE SHANTY OR TRAILER ON STREET', 'TREE PITS',
# ...

# %%
df.PermitTypeDesc.value_counts()
# Out:
# PLACE EQUIPMENT OTHER THAN CRANE OR SHOV              978448
# UTILITY MANHOLE EMBARGO PERMIT                        852029
# COMMERCIAL REFUSE CONTAINER                           670500
# OCCUPANCY OF SIDEWALK AS STIPULATED                   499398
# OCCUPANCY OF ROADWAY AS STIPULATED                    425296
# REPAIR GAS                                            392268
# MAJOR INSTALLATION - GAS                              384817
# REPAIR SIDEWALK                                       332945
# D.D.C. CONTRACTOR MAJOR RECONSTRUCTION                315535
# REPAIR WATER                                          241336
# PLACE CONTAINER ON THE STREET                         232814
# PLACE MATERIAL ON STREET                              225544
# CROSSING SIDEWALK                                     210259
# COMMERCIAL REFUSE CONTAINER CRITICAL STS              184157
# REPAIR GAS - PROTECTED                                183270
# ...

# %%
df.PermitSeriesShortDesc.value_counts()
# Out:
# STREET OPENING PERMIT                   4675317
# BUILDING OPERATION PERMIT               3091192
# MANHOLE EMBARGO PERMIT                   855477
# COMMERICAL REFUSE CONTAINER PERMIT       854657
# SIDEWALK CONSTRUCTION PERMIT             552679
# OVERSIZED VEHICLES                       244508
# DOT IN-HOUSE PAVING AND MILLING          238106
# MOFT&B PERMIT                             57697
# MISCELLANEOUS CASH RECEIPTS               56553
# CANOPY PERMIT                             37992
# PLACE EQUIPMENT - AUTOMATED SERIES        19125
# NYPD PERMIT                               18037
# CAU(SAPO) PERMIT                          16958
# SHUNTS, STEAMSTACKS & NITROGEN TANKS      10599
# APPROVAL REQUEST TO PERFORM WORK           2677
# VAULT LICENSE                               227
# **Description not found in MOSAICS**        219
# PARKS PERMIT                                 98
# Shunts/SteamStacks/NitrogenTanks              1
# Name: PermitSeriesShortDesc, dtype: int64
